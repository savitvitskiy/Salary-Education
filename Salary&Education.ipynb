# %%
import pandas as pd

# %% [markdown]
# Data from United States Census Bureau 2022
#
# https://data.census.gov/table/ACSST1Y2022.S1901?t=Income%20and%20Poverty&g=010XX00US,$0400000

# %%
df = pd.read_csv("US_Income_2022.csv")

# %%
df.shape
# Out:
# (17, 425)

# %%
df.columns

for col in df.columns[1:]:
    print(col.find('!!'), col[:col.find('!!')])
# Out:
# 13 United States
# 13 United States
# 13 United States
# 13 United States
# 13 United States
# 13 United States
# 13 United States
# 13 United States
# 7 Alabama
# 7 Alabama
# 7 Alabama
# 7 Alabama
# 7 Alabama
# 7 Alabama
# 7 Alabama
# 7 Alabama
# 6 Alaska
# 6 Alaska
# 6 Alaska
# 6 Alaska
# 6 Alaska
# 6 Alaska
# 6 Alaska
# 6 Alaska
# 7 Arizona
# 7 Arizona
# 7 Arizona
# 7 Arizona
# 7 Arizona
# 7 Arizona
# 7 Arizona
# 7 Arizona
# 8 Arkansas
# 8 Arkansas
# 8 Arkansas
# 8 Arkansas
# 8 Arkansas
# 8 Arkansas
# 8 Arkansas
# 8 Arkansas
# 10 California
# 10 California
# 10 California
# 10 California
# 10 California
# 10 California
# 10 California
# 10 California
# 8 Colorado
# 8 Colorado
# 8 Colorado
# 8 Colorado
# 8 Colorado
# 8 Colorado
# 8 Colorado
# 8 Colorado
# 11 Connecticut
# 11 Connecticut
# 11 Connecticut
# 11 Connecticut
# 11 Connecticut
# 11 Connecticut
# 11 Connecticut
# 11 Connecticut
# 8 Delaware
# 8 Delaware
# 8 Delaware
# 8 Delaware
# 8 Delaware
# 8 Delaware
# 8 Delaware
# ...

# %%
df.head(17)
# Out:
#                               Label (Grouping)  \
# 0                                        Total
# 1                            Less than $10,000
# 2                           $10,000 to $14,999
# 3                           $15,000 to $24,999
# 4                           $25,000 to $34,999
# 5                           $35,000 to $49,999
# 6                           $50,000 to $74,999
# 7                           $75,000 to $99,999
# 8                         $100,000 to $149,999
# 9                         $150,000 to $199,999
# 10                            $200,000 or more
# 11                     Median income (dollars)
# 12                       Mean income (dollars)
# 13                           PERCENT ALLOCATED
# 14      Household income in the past 12 months
# 15         Family income in the past 12 months
# 16      Nonfamily income in the past 12 months
#
#    United States!!Households!!Estimate  \
# 0                          129,870,928
# ...

# %%
df.iloc[:, 1:]
# Out:
#    United States!!Households!!Estimate  \
# 0                          129,870,928
# 1                                 5.5%
# 2                                 3.7%
# 3                                 6.8%
# 4                                 7.3%
# 5                                10.7%
# 6                                16.2%
# 7                                12.8%
# 8                                16.9%
# 9                                 8.7%
# 10                               11.5%
# 11                              74,755
# 12                             105,555
# 13                                 NaN
# 14                               37.6%
# 15                                 (X)
# 16                                 (X)
#
#    United States!!Households!!Margin of Error  \
# 0                                    ±136,261
# 1                                        ±0.1
# 2                                        ±0.1
# 3                                        ±0.1
# ...

# %%
df.columns.str.contains('Households!!Estimate') | df.columns.str.contains('Grouping')
# Out:
# array([ True,  True, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False,  True, False, False, False,
# ...

# %%
household_df = df.loc[:, df.columns.str.contains('Households!!Estimate') | df.columns.str.contains('Grouping')][:13]
household_df.head()
# Out:
#          Label (Grouping) United States!!Households!!Estimate  \
# 0                   Total                         129,870,928
# 1       Less than $10,000                                5.5%
# 2      $10,000 to $14,999                                3.7%
# 3      $15,000 to $24,999                                6.8%
# 4      $25,000 to $34,999                                7.3%
#
#   Alabama!!Households!!Estimate Alaska!!Households!!Estimate  \
# 0                     2,016,448                      274,574
# 1                          7.6%                         4.4%
# 2                          5.2%                         2.5%
# 3                          9.3%                         5.4%
# 4                          8.6%                         5.3%
#
#   Arizona!!Households!!Estimate Arkansas!!Households!!Estimate  \
# 0                     2,850,377                      1,216,207
# 1                          5.4%                           7.3%
# ...

# %%
household_df.columns
for col in household_df.columns[1:]:
    print(col[:col.find('!!')])
# Out:
# United States
# Alabama
# Alaska
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# District of Columbia
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Virginia
# Washington
# West Virginia
# Wisconsin
# Wyoming
# Puerto Rico

# %%
# rankings_pd.rename(columns = {'test':'TEST'}, inplace = True)
# household_df.rename(columns = [col[:col.find('!!')] for col in household_df.columns[1:]])

# %%
# rankings_pd.set_axis(['A', 'B', 'C'], axis='columns')
# household_df.set_axis([col[:col.find('!!')] for col in household_df.columns[1:]], axis='columns')

# %%
household_df.columns = [col[:col.find('!!')] for col in household_df.columns]

# %%
household_df = household_df.rename(columns={'Label (Grouping': 'STATE'})

# %%
household_df.head()
# Out:
#                     STATE United States    Alabama   Alaska    Arizona  \
# 0                   Total   129,870,928  2,016,448  274,574  2,850,377
# 1       Less than $10,000          5.5%       7.6%     4.4%       5.4%
# 2      $10,000 to $14,999          3.7%       5.2%     2.5%       3.0%
# 3      $15,000 to $24,999          6.8%       9.3%     5.4%       6.2%
# 4      $25,000 to $34,999          7.3%       8.6%     5.3%       7.3%
#
#     Arkansas  California   Colorado Connecticut Delaware  ...  Tennessee  \
# 0  1,216,207  13,550,586  2,384,584   1,433,635  402,334  ...  2,846,684
# 1       7.3%        4.8%       4.1%        5.1%     4.0%  ...       5.4%
# 2       5.9%        3.2%       2.5%        3.2%     2.6%  ...       4.3%
# 3       9.5%        5.5%       5.4%        5.9%     5.8%  ...       7.8%
# 4       9.1%        5.9%       5.8%        6.0%     7.1%  ...       8.2%
#
#         Texas       Utah  Vermont   Virginia Washington West Virginia  \
# ...

# %%
# household_df = household_df.T

# %%
# household_df.reset_index()

# %%
household_df = household_df.set_index('STATE').T

# %%
household_df.head()
# Out:
# STATE                Total     Less than $10,000     $10,000 to $14,999  \
# United States  129,870,928                  5.5%                   3.7%
# Alabama          2,016,448                  7.6%                   5.2%
# Alaska             274,574                  4.4%                   2.5%
# Arizona          2,850,377                  5.4%                   3.0%
# Arkansas         1,216,207                  7.3%                   5.9%
#
# STATE             $15,000 to $24,999     $25,000 to $34,999  \
# United States                   6.8%                   7.3%
# Alabama                         9.3%                   8.6%
# Alaska                          5.4%                   5.3%
# Arizona                         6.2%                   7.3%
# Arkansas                        9.5%                   9.1%
#
# STATE             $35,000 to $49,999     $50,000 to $74,999  \
# United States                  10.7%                  16.2%
# ...

# %%
household_df = household_df.sort_index(axis=0)

# %%
household_df.head()
# Out:
# STATE            Total     Less than $10,000     $10,000 to $14,999  \
# Alabama      2,016,448                  7.6%                   5.2%
# Alaska         274,574                  4.4%                   2.5%
# Arizona      2,850,377                  5.4%                   3.0%
# Arkansas     1,216,207                  7.3%                   5.9%
# California  13,550,586                  4.8%                   3.2%
#
# STATE          $15,000 to $24,999     $25,000 to $34,999  \
# Alabama                      9.3%                   8.6%
# Alaska                       5.4%                   5.3%
# Arizona                      6.2%                   7.3%
# Arkansas                     9.5%                   9.1%
# California                   5.5%                   5.9%
#
# STATE          $35,000 to $49,999     $50,000 to $74,999  \
# Alabama                     12.0%                  16.7%
# Alaska                       9.1%                  15.8%
# ...

# %% [markdown]
# Data from National Education Assocation 2022 - 2023
#
# TEACHER SALARY BENCHMARK AVERAGES: https://www.nea.org/resource-library/educator-pay-and-student-spending-how-does-your-state-rank/starting-teacher
#
# STARTING TEACHER PAY DATA:  https://www.nea.org/resource-library/educator-pay-and-student-spending-how-does-your-state-rank/starting-teacher
#
# *Higher paying districts are more likely to offer advanced degree supplements than are lower paying districts, resulting in average Top Master’s being greater than average Top Salary.

# %%
df_2 = pd.read_csv("Teacher_Starting_Salary.csv")

# %%
df_2.shape
# Out:
# (53, 9)

# %%
df_2.columns
# Out:
# Index(['STATE', 'STARTING SALARY', 'RANK', '$40K DISTRICTS',
#        'DISTRICT PERCENT', '$40K TEACHERS', 'TEACHER PERCENT',
#        'STARTING SALARY 2021-2022', 'SALARY CHANGE'],
#       dtype='object')

# %%
df_2.head()
# Out:
#         STATE STARTING SALARY RANK $40K DISTRICTS DISTRICT PERCENT  \
# 0     Alabama         $43,679   23            138          100.00%
# 1      Alaska         $51,207    6             46          100.00%
# 2     Arizona         $44,124   21            117           81.80%
# 3    Arkansas         $37,907   48             47           20.20%
# 4  California         $55,283    4            833           97.80%
#
#   $40K TEACHERS TEACHER PERCENT STARTING SALARY 2021-2022 SALARY CHANGE
# 0        38,133         100.00%                   $41,974         4.10%
# 1         7,008         100.00%                   $50,083         2.20%
# 2        45,381          93.90%                   $41,791         5.60%
# 3        18,805          50.80%                   $37,168         2.00%
# 4       239,022         100.00%                   $51,904         6.50%

# %%
starting_df = df_2.iloc[:, :8:7]

# %%
starting_df.head()
# Out:
#         STATE STARTING SALARY 2021-2022
# 0     Alabama                   $41,974
# 1      Alaska                   $50,083
# 2     Arizona                   $41,791
# 3    Arkansas                   $37,168
# 4  California                   $51,904

# %%
starting_df = starting_df.set_index('STATE')

# %%
starting_df.head()
# Out:
#            STARTING SALARY 2021-2022
# STATE
# Alabama                      $41,974
# Alaska                       $50,083
# Arizona                      $41,791
# Arkansas                     $37,168
# California                   $51,904

# %% [markdown]
# AVERAGE TEACHER SALARY DATA: https://www.nea.org/resource-library/educator-pay-and-student-spending-how-does-your-state-rank/teacher
#
# Note: Connecticut, District of Columbia, Montana, and Rhode Island salary averages are estimated. National averages are weighted by the number of teachers in each state. Source: NEA Rankings & Estimates, April 2024

# %%
df_3 = pd.read_csv("Teacher_Avg_Salary.csv")

# %%
df_3.shape
# Out:
# (52, 7)

# %%
df_3.columns
# Out:
# Index(['STATE', 'SALARY 2021-22', 'RANK 2021-22', 'SALARY 2022-23',
#        'RANK 2022-23', '2021-22 TO 2022-23 PERCENT CHANGE',
#        '2021-22 TO 2022-23 CHANGE RANK'],
#       dtype='object')

# %%
df_3.head()
# Out:
#         STATE SALARY 2021-22 RANK 2021-22 SALARY 2022-23 RANK 2022-23  \
# 0     Alabama        $55,882           34        $60,441           31
# 1      Alaska        $74,167           10        $76,371           10
# 2     Arizona        $56,775           32        $60,275           32
# 3    Arkansas        $52,610           45        $54,309           45
# 4  California        $88,508            3        $95,160            1
#
#   2021-22 TO 2022-23 PERCENT CHANGE 2021-22 TO 2022-23 CHANGE RANK
# 0                             8.20%                              3
# 1                             3.00%                             33
# 2                             6.20%                              8
# 3                             3.20%                             24
# 4                             7.50%                              4

# %%
average_df = df_3.iloc[:, :2]

# %%
average_df.head()
# Out:
#         STATE SALARY 2021-22
# 0     Alabama        $55,882
# 1      Alaska        $74,167
# 2     Arizona        $56,775
# 3    Arkansas        $52,610
# 4  California        $88,508

# %%
average_df = average_df.set_index('STATE')

# %%
average_df.head()
# Out:
#            SALARY 2021-22
# STATE
# Alabama           $55,882
# Alaska            $74,167
# Arizona           $56,775
# Arkansas          $52,610
# California        $88,508

# %%
# pd.merge(household_df, starting_df)

# %%
# pd.concat([household_df, starting_df])

# %%
household_df.join(starting_df.join(average_df))
# Out:
#                             Total     Less than $10,000  \
# Alabama                 2,016,448                  7.6%
# Alaska                    274,574                  4.4%
# Arizona                 2,850,377                  5.4%
# Arkansas                1,216,207                  7.3%
# California             13,550,586                  4.8%
# Colorado                2,384,584                  4.1%
# Connecticut             1,433,635                  5.1%
# Delaware                  402,334                  4.0%
# District of Columbia      326,970                  6.8%
# Florida                 8,826,394                  5.6%
# Georgia                 4,092,467                  5.6%
# Hawaii                    494,827                  5.3%
# Idaho                     717,151                  3.8%
# Illinois                5,056,360                  5.9%
# Indiana                 2,726,489                  5.6%
# Iowa                    1,330,995                  4.3%
# ...

# %% [markdown]
# # Graph Info Copied from other Notebook

# %% [markdown]
# ### Minimum Wage

# %%
# top_5_min = df_min_wage[df_min_wage['State'] != 'NATIONAL'].nlargest(5, 'Annual Salary')
# bottom_5_min = df_min_wage[df_min_wage['State'] != 'NATIONAL'].nsmallest(5, 'Annual Salary').sort_values(by='Annual Salary', ascending=False)

# pov_value = df_pov_guid['National_PG'].min()

# fig, axs = plt.subplots(1, 2, figsize=(15, 6), sharey=True) 

# axs[0].bar(top_5_min['State'], top_5_min['Annual Salary'], color='skyblue')
# axs[0].axhline(pov_value, color='red', linewidth=2, linestyle='--', label=f'Poverty Line')
# axs[0].set_title('Highest 5 Salaries')
# axs[0].set_xlabel('State')
# axs[0].set_ylabel('Salary')
# axs[0].legend()

# axs[1].bar(bottom_5_min['State'], bottom_5_min['Annual Salary'], color='lightcoral')
# axs[1].axhline(pov_value, color='red', linewidth=2, linestyle='--', label=f'Poverty Line')
# axs[1].set_title('Lowest 5 Salaries')
# axs[1].set_xlabel('State')
# axs[1].set_ylabel('Salary')
# axs[1].legend()

# fig.suptitle('Minimum Wage Salaries', fontsize=16)

# plt.show()

# %% [markdown]
# ### Living Wage

# %%
# top_5_liv = df_liv_wage.nlargest(5, 'Annual Salary')
# bottom_5_liv = df_liv_wage.nsmallest(5, 'Annual Salary').sort_values(by='Annual Salary', ascending=False)

# fig, axs = plt.subplots(1, 2, figsize=(15, 6), sharey=True) 

# axs[0].bar(top_5_liv['State'], top_5_liv['Annual Salary'], color='skyblue')
# axs[0].axhline(pov_value, color='red', linewidth=2, linestyle='--', label=f'Poverty Line')
# axs[0].set_title('Highest 5 Salaries')
# axs[0].set_xlabel('State')
# axs[0].set_ylabel('Salary')
# axs[0].legend()

# axs[1].bar(bottom_5_liv['State'], bottom_5_liv['Annual Salary'], color='lightcoral')
# axs[1].axhline(pov_value, color='red', linewidth=2, linestyle='--', label=f'Poverty Line')
# axs[1].set_title('Lowest 5 Salaries')
# axs[1].set_xlabel('State')
# axs[1].set_ylabel('Salary')
# axs[1].legend()

# fig.suptitle('Living Wage Salaries', fontsize=16)

# plt.tight_layout()

# plt.show()

# %% [markdown]
# ### Median & Average Salaries

# %%
# top_5_sal = df_salaries.sort_values(by='Median Salary').nlargest(5, 'Median Salary')
# bottom_5_sal = df_salaries.sort_values(by='Median Salary').nsmallest(5, 'Median Salary').sort_values(by='Median Salary', ascending=False)

# barWidth = 0.25

# r1 = np.arange(len(top_5_min['State']))
# r2 = [x + barWidth for x in r1]

# fig, axs = plt.subplots(1, 2, figsize=(15, 6), sharey=True) 

# axs[0].bar(r1, top_5_sal['Median Salary'], color='skyblue', width=barWidth, label='Median Salary')
# axs[0].bar(r2, top_5_sal['Average Salary'], color='blue', width=barWidth, label='Average Salary')
# axs[0].axhline(pov_value, color='red', linewidth=2, linestyle='--', label=f'Poverty Line')
# axs[0].set_title('Highest 5 Median Salaries')
# axs[0].set_xlabel('State')
# axs[0].set_ylabel('Salary')
# axs[0].set_xticks([r + barWidth / 2 for r in range(len(top_5_sal['State']))], top_5_sal['State'])
# axs[0].legend()

# axs[1].bar(r1, bottom_5_sal['Median Salary'], color='coral', width=barWidth, label='Median Salary')
# axs[1].bar(r2, bottom_5_sal['Average Salary'], color='pink', width=barWidth, label='Average Salary')
# axs[1].axhline(pov_value, color='red', linewidth=2, linestyle='--', label=f'Poverty Line')
# axs[1].set_title('Lowest 5 Median Salaries')
# axs[1].set_xlabel('State')
# axs[1].set_ylabel('Salary')
# axs[1].set_xticks([r + barWidth / 2 for r in range(len(bottom_5_sal['State']))], bottom_5_sal['State'])
# axs[1].legend()

# fig.suptitle('Median & Average Salaries', fontsize=16)

# plt.tight_layout()

# plt.show()

# %% [markdown]
# ### Starting Teacher Salary

# %%
# top_5_star = df_star_sal.nlargest(5, 'Starting Salary')
# bottom_5_star = df_star_sal.nsmallest(5, 'Starting Salary').sort_values(by='Starting Salary', ascending=False)

# fig, axs = plt.subplots(1, 2, figsize=(15, 6), sharey=True) 

# axs[0].bar(top_5_star['State'], top_5_star['Starting Salary'], color='skyblue')
# axs[0].axhline(pov_value, color='red', linewidth=2, linestyle='--', label=f'Poverty Line')
# axs[0].set_title('Highest 5 Salaries')
# axs[0].set_xlabel('State')
# axs[0].set_ylabel('Salary')
# axs[0].legend()

# axs[1].bar(bottom_5_star['State'], bottom_5_star['Starting Salary'], color='lightcoral')
# axs[1].axhline(pov_value, color='red', linewidth=2, linestyle='--', label=f'Poverty Line')
# axs[1].set_title('Lowest 5 Salaries')
# axs[1].set_xlabel('State')
# axs[1].set_ylabel('Salary')
# axs[1].legend()

# fig.suptitle('Starting Salaries for Teachers', fontsize=16)

# plt.tight_layout()

# plt.show()

# %% [markdown]
# ### Average Teacher Salary

# %%
# top_5_avg = df_avg_sal.nlargest(5, '2022 - 2023')
# bottom_5_avg = df_avg_sal.nsmallest(5, '2022 - 2023').sort_values(by='2022 - 2023', ascending=False)

# fig, axs = plt.subplots(1, 2, figsize=(15, 6), sharey=True) 

# axs[0].bar(top_5_avg['State'], top_5_avg['2022 - 2023'], color='skyblue')
# axs[0].axhline(pov_value, color='red', linewidth=2, linestyle='--', label=f'Poverty Line')
# axs[0].set_title('Highest 5 Salaries')
# axs[0].set_xlabel('State')
# axs[0].set_ylabel('Salary')
# axs[0].legend()

# axs[1].bar(bottom_5_avg['State'], bottom_5_avg['2022 - 2023'], color='lightcoral')
# axs[1].axhline(pov_value, color='red', linewidth=2, linestyle='--', label=f'Poverty Line')
# axs[1].set_title('Lowest 5 Salaries')
# axs[1].set_xlabel('State')
# axs[1].set_ylabel('Salary')
# axs[1].legend()

# fig.suptitle('Average Salaries for Teachers', fontsize=16)

# plt.tight_layout()

# plt.show()
